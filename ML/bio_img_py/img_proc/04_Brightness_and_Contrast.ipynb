# %% [markdown]
# # Brightness and Contrast

# %% [markdown]
# When visualizing images in Jupyter notebooks it is important to show them in a way that a reader can see what we're writing about. Therefore, adjusting brightness and contrast is important. We can do this by modifying the _display range_, the range of displayed grey values.
#
# For demonstration purposes we use the [cells3d example image of scikit-image](https://scikit-image.org/docs/stable/api/skimage.data.html#skimage.data.cells3d).

# %%
import skimage

skimage.data.download_all()
# Out:
# Downloading file 'color/tests/data/lab_array_a_10.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_a_10.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_a_2.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_a_2.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_a_r.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_a_r.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_b_10.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_b_10.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_b_2.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_b_2.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_b_r.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_b_r.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_c_10.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_c_10.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_c_2.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_c_2.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_c_r.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_c_r.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_d50_10.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_d50_10.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_d50_2.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_d50_2.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_d50_r.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_d50_r.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_d55_10.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_d55_10.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_d55_2.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_d55_2.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_d55_r.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_d55_r.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_d65_10.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_d65_10.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_d65_2.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_d65_2.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_d65_r.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_d65_r.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_d75_10.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_d75_10.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_d75_2.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_d75_2.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/lab_array_e_2.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/lab_array_e_2.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/luv_array_a_10.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/luv_array_a_10.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/luv_array_a_2.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/luv_array_a_2.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/luv_array_a_r.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/luv_array_a_r.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/luv_array_b_10.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/luv_array_b_10.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/luv_array_b_2.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/luv_array_b_2.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/luv_array_b_r.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/luv_array_b_r.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/luv_array_c_10.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/luv_array_c_10.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/luv_array_c_2.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/luv_array_c_2.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'color/tests/data/luv_array_c_r.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/color/tests/data/luv_array_c_r.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 
to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'restoration/tests/astronaut_rl.npy' from 'https://gitlab.com/scikit-image/data/-/raw/2cdc5ce89b334d28f06a58c9f0ca21aa6992a5ba/astronaut_rl.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'restoration/tests/camera_rl.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/restoration/tests/camera_rl.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'restoration/tests/camera_unsup.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/restoration/tests/camera_unsup.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'restoration/tests/camera_unsup2.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/restoration/tests/camera_unsup2.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'restoration/tests/camera_wiener.npy' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/restoration/tests/camera_wiener.npy' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'registration/tests/data/OriginalX-130Y130.png' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/registration/tests/data/OriginalX-130Y130.png' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'registration/tests/data/OriginalX130Y130.png' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/registration/tests/data/OriginalX130Y130.png' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'registration/tests/data/OriginalX75Y75.png' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/registration/tests/data/OriginalX75Y75.png' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'registration/tests/data/TransformedX-130Y130.png' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/registration/tests/data/TransformedX-130Y130.png' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'registration/tests/data/TransformedX130Y130.png' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/registration/tests/data/TransformedX130Y130.png' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'registration/tests/data/TransformedX75Y75.png' from 'https://github.com/scikit-image/scikit-image/raw/v0.22.0/skimage/registration/tests/data/TransformedX75Y75.png' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'data/brain.tiff' from 'https://gitlab.com/scikit-image/data/-/raw/2cdc5ce89b334d28f06a58c9f0ca21aa6992a5ba/brain.tiff' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'data/cells3d.tif' from 'https://gitlab.com/scikit-image/data/-/raw/2cdc5ce89b334d28f06a58c9f0ca21aa6992a5ba/cells3d.tif' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'data/palisades_of_vogt.tif' from 'https://gitlab.com/scikit-image/data/-/raw/b2bc880f3bac23a583724befe8388dae368c52fe/in-vivo-cornea-spots.tif' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'data/kidney.tif' from 'https://gitlab.com/scikit-image/data/-/raw/2cdc5ce89b334d28f06a58c9f0ca21aa6992a5ba/kidney-tissue-fluorescence.tif' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'data/lily.tif' from 'https://gitlab.com/scikit-image/data/-/raw/2cdc5ce89b334d28f06a58c9f0ca21aa6992a5ba/lily-of-the-valley-fluorescence.tif' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'data/mitosis.tif' from 'https://gitlab.com/scikit-image/data/-/raw/2cdc5ce89b334d28f06a58c9f0ca21aa6992a5ba/AS_09125_050116030001_D03f00d0.tif' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'data/skin.jpg' from 'https://gitlab.com/scikit-image/data/-/raw/2cdc5ce89b334d28f06a58c9f0ca21aa6992a5ba/Normal_Epidermis_and_Dermis_with_Intradermal_Nevus_10x.JPG' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'data/pivchallenge-B-B001_1.tif' from 'https://gitlab.com/scikit-image/data/-/raw/2cdc5ce89b334d28f06a58c9f0ca21aa6992a5ba/pivchallenge/B/B001_1.tif' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'data/pivchallenge-B-B001_2.tif' from 'https://gitlab.com/scikit-image/data/-/raw/2cdc5ce89b334d28f06a58c9f0ca21aa6992a5ba/pivchallenge/B/B001_2.tif' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'data/protein_transport.tif' from 'https://gitlab.com/scikit-image/data/-/raw/2cdc5ce89b334d28f06a58c9f0ca21aa6992a5ba/NPCsingleNucleus.tif' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.
# Downloading file 'data/solidification.tif' from 'https://gitlab.com/scikit-image/data/-/raw/2cdc5ce89b334d28f06a58c9f0ca21aa6992a5ba/nickel_solidification.tif' to 'C:\Users\phoni\AppData\Local\scikit-image\scikit-image\Cache\0.22.0'.

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.data import cells3d

# %% [markdown]
# The `cells3d` dataset is a 4D-image. Using array-acces we extract a single 2D slice and show it.

# %%
image = cells3d()[30,0]
image.shape
# Out:
# (256, 256)

# %%
plt.imshow(image, cmap='gray')
plt.colorbar()

# %% [markdown]
# Notice that here the colorbar ranges from 0 to about 45000. The matplotlib `plt.imshow()` function adjusts the image contrast to the minimal and maximal values.

# %% [markdown]
# The minimal and maximal pixel values can also be obtained like this:

# %%
min_value = image.min()
max_value = image.max()
print('min value = ', min_value)
print('max value = ', max_value)
# Out:
# min value =  277
# max value =  44092

# %% [markdown]
# If we want to increase brightness, i.e., the perception that the image is emitting more light, we can configure the display range by setting its minimum `vmin` and maximum `vmax`. This improves visibility of the membranes.

# %%
plt.imshow(image, cmap='gray', vmax=10000)
plt.colorbar()

# %% [markdown]
# ## Adjusting visualization independent from the specific image
# The next image we open may, or may not, have a similar grey-value range. Therefore, we could inspect the histogram of the image and guess a better threshold manually.

# %%
plt.hist(image.ravel())
# Out:
# (array([5.8622e+04, 5.6930e+03, 9.7800e+02, 1.6900e+02, 5.5000e+01,
#         1.0000e+01, 5.0000e+00, 1.0000e+00, 2.0000e+00, 1.0000e+00]),
#  array([  277. ,  4658.5,  9040. , 13421.5, 17803. , 22184.5, 26566. ,
#         30947.5, 35329. , 39710.5, 44092. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Histograms of images are often shown with a [log-scale](https://en.wikipedia.org/wiki/Logarithmic_scale).

# %%
plt.hist(image.ravel(), log=True)
# Out:
# (array([5.8622e+04, 5.6930e+03, 9.7800e+02, 1.6900e+02, 5.5000e+01,
#         1.0000e+01, 5.0000e+00, 1.0000e+00, 2.0000e+00, 1.0000e+00]),
#  array([  277. ,  4658.5,  9040. , 13421.5, 17803. , 22184.5, 26566. ,
#         30947.5, 35329. , 39710.5, 44092. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Obviously this image has a lot of dark grey values (< 20000) and little values > 40000.
#
# It might make sense to configure the visualization using a percentage. Assume we want to visualize the image in a way so that 95% of the pixels are within range. We can do this using [numpy's percentile method](https://numpy.org/doc/stable/reference/generated/numpy.percentile.html). We will also come back to percentiles by the end of the semester.

# %%
upper_limit = np.percentile(image, 95)
upper_limit
# Out:
# 6580.0

# %%
plt.imshow(image, cmap='gray', vmax=upper_limit)
plt.colorbar()

# %% [markdown]
# # Exercise

# %% [markdown]
# The `cells3d` dataset contains another channel showing the nuclei of the cells. Visualize it so that 99% of the lower grey values are visualized properly.

# %%
nuclei = cells3d()[30,1]
nuclei.shape
# Out:
# (256, 256)

# %%
plt.imshow(nuclei, cmap='gray')
plt.colorbar()

# %%
min_value = nuclei.min()
max_value = nuclei.max()
print('min value = ', min_value)
print('max value = ', max_value)
# Out:
# min value =  1091
# max value =  58327

# %%
upper_limit = np.percentile(nuclei, 99)
upper_limit
# Out:
# 27077.0

# %%
plt.imshow(nuclei, cmap='gray', vmax = upper_limit )
plt.colorbar()
